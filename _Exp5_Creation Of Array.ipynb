# %%
# Experiment No: 5

# %%
#AIM : creating dimensional array

# %%
# Name: Shraddha Sonekar
# Roll no: 58
# Sec:  CSE-DS
# Subject:ET-I

# %%
import numpy as np

# %%
# Creating 1D array. (square bracketin round = array)(square bracket=tuple)
a1=np.array([10,20,30,40])

# %%
a1
# Out:
# array([10, 20, 30, 40])

# %%
#Creating 2D array
a2=np.array([[11,30,20,40],[34,89,47,34]])

# %%
a2
# Out:
# array([[11, 30, 20, 40],
#        [34, 89, 47, 34]])

# %%
#Creating 2D array using matrix
a3=np.matrix('11,23;33,45;67,78')
print(a3)
# Out:
# [[11 23]
#  [33 45]
#  [67 78]]

# %%
#Creating array of 25 random interger between 20 and 23 (inclusive)
arr=np.random.randint(20,24,size=25)
print(arr)
# Out:
# [22 21 20 23 22 20 21 21 22 23 21 23 21 23 21 22 20 20 22 22 20 20 20 20
#  23]
