# %%
#Exp no 03
#Aim: centrel tendency of measure mean median mode

# %%
# Name: shraddha
#Roll no:58
#sec: c
#subject:ET
#date:01/08/25

# %%
age=[24,34,43,21,20,22,23,45,43,20,21,32,]

# %%
age

# %%
print(age)

# %%
import statistics

# %%
a=statistics.mean(age)

# %%
a

# %%
b=statistics.median(age)

# %%
b

# %%
c=statistics.mode(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 c=statistics.mode(age)
#
# NameError: name 'statistics' is not defined

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
import numpy as np
x=np.array([1,2,3,4,5,6,7,2,5,4,7,6,7])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 2, 5, 4, 7, 6, 7])

# %%
print(np.mean(x))
# Out:
# 4.538461538461538

# %%
print(np.median(x))
# Out:
# 5.0

# %%
print(np.mode(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(np.mode(x))
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(7), count=np.int64(3))

# %%
print(np.std(x))
# Out:
# 1.9851519847021446

# %%
print(np.var(x))
# Out:
# 3.940828402366864
